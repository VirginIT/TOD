# %%
import json

# %%
from bs4 import BeautifulSoup

with open(r"C:\Users\Stepan Maximov\Downloads\_up_2020_pmi.xml", 'r', encoding='UTF-8') as f:
    ab = BeautifulSoup(f, 'xml')
ab
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <уч_план>
# <дисциплина Всего="144" ЗЕ="4" ЗЕ-экз="3" ЗЕ1="4" СРС="76" СРС-сем="40" СРС-экз="36" СРС1="20" СРС2="56" ауд="68" зачеты="3" кафедра="Философия" код="Г_Б.1.1" лекции="32" лекции1="16" лекции2="16" название="Философия" реферат="4" сем1="3" сем2="4" семинары="36" семинары1="18" семинары2="18" спец="ПМИ-2014" час-нед1="2" час-нед2="2" экзамены="4"/>
# <дисциплина Всего="216" ДТЗ="1.2" ЗЕ="6" ЗЕ1="6" КР="33" СРС="80" СРС1="40" СРС3="40" ауд="136" зачеты="1.2" кафедра="ИЯ-3" код="Г_Б.1.2" контр="1.2" название="Иностранный язык" семинары="136" семинары1="68" семинары2="68" час-нед1="4" час-нед2="4" экзамены="22"/>
# <дисциплина Всего="144" ЗЕ="4" ЗЕ-экз="3" ЗЕ1="4" СРС="94" СРС-сем="58" СРС-экз="36" СРС1="94" ауд="50" кафедра="ЭИиИЭУ" код="Г_Б.1.3" лекции="18" лекции1="18" название="История" реферат="1" сем1="1" семинары="32" семинары1="32" спец="ПМИ-2014" час-нед1="3" экзамены="1"/>
# ...

# %%
dic = ab.find_all('дисциплина')
for d in dic:
    if d.has_attr('кафедра'):
        print(f"{d['название']}: {d['кафедра']}")
# Out:
# Философия: Философия
# Иностранный язык: ИЯ-3
# История: ЭИиИЭУ
# Экономика (микроэкономика): Микроэкономика
# Социология: ТеорСоциология
# Экономика (макроэкономика): Макроэкономика
# Право: ТиИГП
# Иностранный язык 1: ИЯ-3
# Деловой иностранный язык: ИЯ-3
# Математический анализ 1: Математика 1
# Математический анализ 2: Математика 1
# Математический анализ 3: Математика 1
# Комплексный анализ: Математика 1
# Функциональный анализ: Математика 1
# Алгебра и геометрия 1: Математика 1
# Физика: ПМ
# Основы информатики: ПИ
# Архитектура комрьютеров: ПИ
# Компьютерная графика: ПИ
# Алгебра и геометрия 2: Математика 1
# Эконометрика: МЭиИС
# Системный анализ : САвЭ
# Исследование операций: ПМ
# Теория игр: МЭиИС
# Случайные процессы в финансах и экономике: ПМ
# Нечеткие множества и мягкие вычисления: Математика 1
# Теория финансово-экономических систем массового обслуживания: МЭиИС
# Вариационные исчисления: Математика 1
# Теория оптимального управления: ПМ
# ...
